# %% [markdown]
# <a href="https://colab.research.google.com/github/macodevep/Filtrado_con_pandas/blob/main/filtrado_con_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/mobile_phones_2000.xls')
df
# Out:
#         Brand                Model  Price (USD)  Selling Platform  Rating  \
# 0     OnePlus        Narzo Edge 16      1286.64          Best Buy     3.5
# 1        Sony         Pixel Max 24       728.52              eBay     4.6
# 2     Samsung         Reno Plus 23      1086.68    Official Store     3.4
# 3       Apple   Redmi Note Mini 16      1158.78    Official Store     3.5
# 4        Vivo     P Series Edge 13      1656.05  Reliance Digital     4.9
# ...       ...                  ...          ...               ...     ...
# 1995     Sony          Reno Max 23       210.87              eBay     4.7
# 1996   Xiaomi       iPhone Mini 21      1638.88          Best Buy     3.3
# 1997    Nokia         Nord Plus 24      1425.14              eBay     3.8
# 1998  OnePlus       Narzo Ultra 25       223.23            Amazon     3.6
# 1999   Google  Redmi Note Turbo 22      1656.45           Walmart     4.4
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# ...

# %% [markdown]
# #Revisamos si hay duplicados

# %%
print(df.duplicated())
num_duplicados = df.duplicated().sum()
if num_duplicados > 0:
  print(f"Hay {num_duplicados} filas duplicadas en el DataFrame.")
else:
  print("No hay filas duplicadas en el DataFrame.")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 2000, dtype: bool
# No hay filas duplicadas en el DataFrame.

# %% [markdown]
# # Podemos ver si nuestro dataset tiene valores nulos

# %%
valores_nulos_por_columna = df.isnull().sum()
print(valores_nulos_por_columna)
# Out:
# Brand                   0
# Model                   0
# Price (USD)             0
# Selling Platform        0
# Rating                  0
# Refresh Rate (Hz)       0
# Screen Size (inches)    0
# RAM (GB)                0
# Storage (GB)            0
# Processor               0
# Camera Setup            0
# dtype: int64

# %% [markdown]
# # Filtrado por columnas

# %%
df['Brand']
# Out:
# 0       OnePlus
# 1          Sony
# 2       Samsung
# 3         Apple
# 4          Vivo
#          ...
# 1995       Sony
# 1996     Xiaomi
# 1997      Nokia
# 1998    OnePlus
# 1999     Google
# Name: Brand, Length: 2000, dtype: object

# %% [markdown]
# # Filtrando dos columnas como lista

# %%
df[['Price (USD)', 'Model']]
# Out:
#       Price (USD)                Model
# 0         1286.64        Narzo Edge 16
# 1          728.52         Pixel Max 24
# 2         1086.68         Reno Plus 23
# 3         1158.78   Redmi Note Mini 16
# 4         1656.05     P Series Edge 13
# ...           ...                  ...
# 1995       210.87          Reno Max 23
# 1996      1638.88       iPhone Mini 21
# 1997      1425.14         Nord Plus 24
# 1998       223.23       Narzo Ultra 25
# 1999      1656.45  Redmi Note Turbo 22
#
# [2000 rows x 2 columns]

# %% [markdown]
# # Filtrado por filas

# %% [markdown]
# filtrado por indices

# %%
df.iloc[0:3]
# Out:
#      Brand          Model  Price (USD) Selling Platform  Rating  \
# 0  OnePlus  Narzo Edge 16      1286.64         Best Buy     3.5
# 1     Sony   Pixel Max 24       728.52             eBay     4.6
# 2  Samsung   Reno Plus 23      1086.68   Official Store     3.4
#
#    Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# 0                165                   7.2        16           128
# 1                 90                   6.1         4            64
# 2                 60                   6.2        12            64
#
#              Processor        Camera Setup
# 0  Snapdragon 8+ Gen 1   12MP + 16MP + 5MP
# 1        Dimensity 920    48MP + 8MP + 5MP
# 2          Exynos 2200  200MP + 12MP + 8MP

# %% [markdown]
# filtrado por id

# %%
df.tail()
# Out:
#         Brand                Model  Price (USD) Selling Platform  Rating  \
# 1995     Sony          Reno Max 23       210.87             eBay     4.7
# 1996   Xiaomi       iPhone Mini 21      1638.88         Best Buy     3.3
# 1997    Nokia         Nord Plus 24      1425.14             eBay     3.8
# 1998  OnePlus       Narzo Ultra 25       223.23           Amazon     3.6
# 1999   Google  Redmi Note Turbo 22      1656.45          Walmart     4.4
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# 1995                144                   5.3         8           128
# 1996                144                   6.9         8          1024
# 1997                120                   6.2        16           128
# 1998                 60                   7.2        12           512
# 1999                 60                   5.7        16          1024
#
#                Processor        Camera Setup
# 1995           Helio G99   48MP + 50MP + 5MP
# ...

# %%
df.loc[1995]
# Out:
# Brand                                Sony
# Model                         Reno Max 23
# Price (USD)                        210.87
# Selling Platform                     eBay
# Rating                                4.7
# Refresh Rate (Hz)                     144
# Screen Size (inches)                  5.3
# RAM (GB)                                8
# Storage (GB)                          128
# Processor                       Helio G99
# Camera Setup            48MP + 50MP + 5MP
# Name: 1995, dtype: object

# %% [markdown]
# #Filtrado con loc filas y columnas

# %%
df.tail()
# Out:
#         Brand                Model  Price (USD) Selling Platform  Rating  \
# 1995     Sony          Reno Max 23       210.87             eBay     4.7
# 1996   Xiaomi       iPhone Mini 21      1638.88         Best Buy     3.3
# 1997    Nokia         Nord Plus 24      1425.14             eBay     3.8
# 1998  OnePlus       Narzo Ultra 25       223.23           Amazon     3.6
# 1999   Google  Redmi Note Turbo 22      1656.45          Walmart     4.4
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# 1995                144                   5.3         8           128
# 1996                144                   6.9         8          1024
# 1997                120                   6.2        16           128
# 1998                 60                   7.2        12           512
# 1999                 60                   5.7        16          1024
#
#                Processor        Camera Setup
# 1995           Helio G99   48MP + 50MP + 5MP
# ...

# %% [markdown]
# los primeros corchetes de la izquierda son los indices y los de la derecha son los nombres de las columnas

# %%
df.loc[[1995, 1996] , ['Model'] ]
# Out:
#                Model
# 1995     Reno Max 23
# 1996  iPhone Mini 21

# %% [markdown]
# #Filtrado por condiciones

# %% [markdown]
# filtré dos columnas donde el precio sea menor que 1000 y el rating mayor de 4

# %%
df[(df['Price (USD)'] < 1000) & (df['Rating'] > 4)]
# Out:
#        Brand              Model  Price (USD) Selling Platform  Rating  \
# 1       Sony       Pixel Max 24       728.52             eBay     4.6
# 5       Vivo     P Series 5G 19       390.46         Best Buy     4.4
# 9     Realme   P Series Mini 19       730.09             eBay     4.2
# 10      Vivo  Redmi Note Max 16       268.58         Flipkart     4.3
# 11     Nokia   V Series Lite 20       391.77          Walmart     4.1
# ...      ...                ...          ...              ...     ...
# 1985  Xiaomi    Xperia Ultra 21       247.22       AliExpress     4.6
# 1990  Huawei      Pixel Edge 17       916.61   Official Store     4.8
# 1993  Realme       Mate Lite 14       874.73          Walmart     4.4
# 1994    Oppo     Pixel Turbo 24       733.56   Official Store     4.4
# 1995    Sony        Reno Max 23       210.87             eBay     4.7
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# ...

# %% [markdown]
# #Filtraré la columna BRAND donde me muestra sólo las filas que tengan SONY

# %%
df[df['Brand'].str.contains('Sony')]
# Out:
#      Brand              Model  Price (USD) Selling Platform  Rating  \
# 1     Sony       Pixel Max 24       728.52             eBay     4.6
# 6     Sony  Galaxy S Ultra 22      1172.46         Best Buy     3.2
# 17    Sony      Pixel Plus 18      1414.63   Official Store     3.1
# 27    Sony        Narzo SE 13       927.02       AliExpress     3.4
# 30    Sony        Reno Pro 25      1083.16         Best Buy     3.6
# ...    ...                ...          ...              ...     ...
# 1952  Sony     Xperia Lite 24       693.03           Amazon     4.9
# 1958  Sony     Moto G Mini 12      1463.61       AliExpress     3.2
# 1971  Sony      Reno Ultra 11      1834.01          Walmart     3.1
# 1982  Sony   V Series Plus 24      1068.95           Amazon     4.8
# 1995  Sony        Reno Max 23       210.87             eBay     4.7
#
#       Refresh Rate (Hz)  Screen Size (inches)  RAM (GB)  Storage (GB)  \
# 1                    90                   6.1         4            64
# ...
